# %%
from src.preprocessing import clean_inequality_data
import pandas as pd

# soit on relance le nettoyage :
df_clean = clean_inequality_data()

# soit on lit simplement le fichier déjà créé :
# df_clean = pd.read_excel("data/inequality_clean.xlsx")

df_clean.head()
